# %% [markdown]
# ## Non re-inventare la ruota!
#
# Python mette già a disposizione numerose librerie per il calcolo scientifico e la rappresentazione grafica dei risultati.
#
#     NumPy : creazione e manipolazioni di array, calcolo scientifico, algebra, statistica,...
#     Pandas : gestione dei dati, dataset organizzati in dataframes
#     SciPy : calcolo scientifico, algebra, integrazione di equazioni
#     Scikit-learn : Machine Learning e Pattern Recognition
#     Matplotlib : plot e grafica
#     Seaborn : plot e grafica in maniera veloce

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
###
##  X label name = Month Number
##  Y label name = Total profit
##
df =pd.read_csv('https://frenzy86.s3.eu-west-2.amazonaws.com/fav/company_sales_data.csv')

# %%
df.head(20)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
df.tail(8)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
import calendar

for month_idx in range(1, 13):
    print (calendar.month_name[month_idx])
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
month_word = {
1:'January',
2:'February',
3:'March',
4:'April',
5:'May',
6:'June',
7:'July',
8:'August',
9:'September',
10:'October',
11:'November',
12:'December'
}

# %%
df['month_number'] = df['month_number'].map(month_word)
df
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0       January       2500      1500        5200         9200     1200
# 1      February       2630      1200        5100         6100     2100
# 2         March       2140      1340        4550         9550     3550
# 3         April       3400      1130        5870         8870     1870
# 4           May       3600      1740        4560         7760     1560
# 5          June       2760      1555        4890         7490     1890
# 6          July       2980      1120        4780         8980     1780
# 7        August       3700      1400        5860         9960     2860
# 8     September       3540      1780        6100         8100     2100
# 9       October       1990      1890        8300        10300     2300
# 10     November       2340      2100        7300        13300     2400
# 11     December       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
df.shape
# Out:
# (12, 9)

# %%
df.describe()
# Out:
#          facecream     facewash   toothpaste   bathingsoap      shampoo  \
# count    12.000000    12.000000    12.000000     12.000000    12.000000
# mean   2873.333333  1542.916667  5825.833333   9500.833333  2117.500000
# std     584.595172   316.733745  1242.032486   2348.095779   617.724931
# min    1990.000000  1120.000000  4550.000000   6100.000000  1200.000000
# 25%    2460.000000  1305.000000  4862.500000   8015.000000  1795.000000
# 50%    2830.000000  1527.500000  5530.000000   9090.000000  1995.000000
# 75%    3435.000000  1765.000000  6400.000000  10045.000000  2325.000000
# max    3700.000000  2100.000000  8300.000000  14400.000000  3550.000000
#
#        moisturizer  total_units   total_profit
# count    12.000000     12.00000      12.000000
# mean   1542.916667  26027.50000  260275.000000
# std     316.733745   7014.36594   70143.659404
# min    1120.000000  18330.00000  183300.000000
# 25%    1305.000000  21065.00000  210650.000000
# 50%    1527.500000  22935.00000  229350.000000
# 75%    1765.000000  29667.50000  296675.000000
# max    2100.000000  41280.00000  412800.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month_number  12 non-null     object
#  1   facecream     12 non-null     int64
#  2   facewash      12 non-null     int64
#  3   toothpaste    12 non-null     int64
#  4   bathingsoap   12 non-null     int64
#  5   shampoo       12 non-null     int64
#  6   moisturizer   12 non-null     int64
#  7   total_units   12 non-null     int64
#  8   total_profit  12 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 992.0+ bytes

# %%
df.isnull().values.sum()
#df.isnull().values.sum(axis=0)
#df.isnull().values.sum(axis=1)
# Out:
# 0

# %%
# Rename a specific
df.rename(columns={'month_number':'month'},inplace=True)
df
# Out:
#         month  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0     January       2500      1500        5200         9200     1200
# 1    February       2630      1200        5100         6100     2100
# 2       March       2140      1340        4550         9550     3550
# 3       April       3400      1130        5870         8870     1870
# 4         May       3600      1740        4560         7760     1560
# 5        June       2760      1555        4890         7490     1890
# 6        July       2980      1120        4780         8980     1780
# 7      August       3700      1400        5860         9960     2860
# 8   September       3540      1780        6100         8100     2100
# 9     October       1990      1890        8300        10300     2300
# 10   November       2340      2100        7300        13300     2400
# 11   December       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
## Create a list form column
profitList = df ['total_profit'].tolist()
monthList  = df ['month'].tolist()

# %%
profitList
# Out:
# [211000,
#  183300,
#  224700,
#  222700,
#  209600,
#  201400,
#  295500,
#  361400,
#  234000,
#  266700,
#  412800,
#  300200]

# %%
monthList
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %%
plt.figure(figsize=(12,8))
plt.plot(monthList, profitList, label = 'Month-wise Profit data of last year');

#       color='r', marker='o', markerfacecolor='k', 
#       linestyle='--', linewidth=3);


plt.xlabel('Months')
plt.ylabel('Profit in dollar')

plt.xticks(monthList)
plt.legend(loc='upper left')
plt.title('Company profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000]);
#plt.xticks([3, 6, 9, 12]);

#plt.show()

# %%
df ['total_profit'].sum()
# Out:
# 3123300

# %%
211000+183300+224700+222700+209600+201400+295500+361400+234000+266700+412800+300200
# Out:
# 3123300

# %%
plt.figure(figsize=(10,5))
ax = plt.gca()
df.plot(kind='line',x='month',y='facecream',ax=plt.gca())
df.plot(kind='line',x='month',y='facewash', color='red', ax=plt.gca())
df.plot(kind='line',x='month',y='toothpaste', color='green', ax=plt.gca())
df.plot(kind='line',x='month',y='bathingsoap', color='orange', ax=plt.gca())
df.plot(kind='line',x='month',y='shampoo', color='black', ax=plt.gca())
df.plot(kind='line',x='month',y='moisturizer', color='cyan', ax=plt.gca())
# Out:
# <Axes: xlabel='month'>

# %%
df.columns[1:-2]
# Out:
# Index(['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo',
#        'moisturizer'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
#product = ['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']
product = df.columns[1:-2]
for i in product:
    ax=plt.gca()
    df.plot(kind='line',x='month',y=i,ax=ax)

# %%
plt.figure(figsize=(10,5))
#product = ['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']
product = df.columns[1:-2]
for i in product:
    ax=plt.gca()
    df.plot(kind='box',x='month',y=i,ax=ax)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 6
#       4 for i in product:
#       5     ax=plt.gca()
# ----> 6     df.plot(kind='box',x='month',y=i,ax=plt.gca())
#
# File c:\Users\libero.bo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\libero.bo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\libero.bo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:452, in MPLPlot.generate(self)
#     450 self._compute_plot_data()
#     451 self._setup_subplots()
# --> 452 self._make_plot()
#     453 self._add_table()
#     454 self._make_legend()
#
# File c:\Users\libero.bo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:198, in BoxPlot._make_plot(self)
#     196 if not self.use_index:
#     197     labels = [pprint_thing(key) for key in range(len(labels))]
# --> 198 self._set_ticklabels(ax, labels)
#
# File c:\Users\libero.bo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:202, in BoxPlot._set_ticklabels(self, ax, labels)
#     200 def _set_ticklabels(self, ax: Axes, labels):
#     201     if self.orientation == "vertical":
# --> 202         ax.set_xticklabels(labels)
#     203     else:
#     204         ax.set_yticklabels(labels)
#
# File c:\Users\libero.bo\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File c:\Users\libero.bo\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File c:\Users\libero.bo\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axis.py:1969, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1965 if isinstance(locator, mticker.FixedLocator):
#    1966     # Passing [] as a list of labels is often used as a way to
#    1967     # remove all tick labels, so only error for > 0 labels
#    1968     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969         raise ValueError(
#    1970             "The number of FixedLocator locations"
#    1971             f" ({len(locator.locs)}), usually from a call to"
#    1972             " set_ticks, does not match"
#    1973             f" the number of labels ({len(labels)}).")
#    1974     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    1975     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (2), usually from a call to set_ticks, does not match the number of labels (1).

# %%
monthList  = df ['month'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()


plt.figure(figsize=(16,10))
plt.plot(monthList, faceCremSalesData,   label = 'Face cream Sales Data', marker='o', linewidth=3)
plt.plot(monthList, faceWashSalesData,   label = 'Face Wash Sales Data',  marker='o', linewidth=3)
plt.plot(monthList, toothPasteSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(monthList, bathingsoapSalesData, label = 'Bathingsoap Sales Data', marker='o', linewidth=3)
plt.plot(monthList, shampooSalesData, label = 'Shampoo Sales Data', marker='o', linewidth=3)
plt.plot(monthList, moisturizerSalesData, label = 'Moisturize Sales Data', marker='o', linewidth=3)

plt.xlabel('Months')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data');

# %%
### CREO UNA LISTA DI VENDITE TOTALI

# %%
df.columns
# Out:
# Index(['month', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
#        'shampoo', 'moisturizer', 'total_units', 'total_profit'],
#       dtype='object')

# %%
labels = ['facecream', 'facewash', 'toothpaste', 'bathingsoap',
       'shampoo', 'moisturizer']
salesData   = [df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste'].sum(), 
         df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()]

# %%
plt.figure(figsize=(12,8))
#plt.axis("equal")

plt.pie(salesData, labels=labels, autopct='%1.1f%%')
plt.legend(loc='upper right')
plt.title('Sales data');
#plt.show()

# %%
### STACKPLOT

# %%
monthList  = df ['month'].tolist()

faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()


plt.figure(figsize=(12,8))

plt.stackplot(monthList, faceCremSalesData, faceWashSalesData, toothPasteSalesData, 
              bathingsoapSalesData, shampooSalesData, moisturizerSalesData) 
              #colors=['m','c','r','k','g','y'])

plt.xlabel('Month Number')
plt.ylabel('Sales unints in Number')
plt.title('Alll product sales data using stack plot');

#plt.show()

# %%
########### PLOTTARE DIRETTAMENTE DA DATAFRAME

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
Data = {'Country': ['USA','Canada','Germany','UK','France'],
        'GDP': [45000,42000,52000,49000,47000]}
  
df = pd.DataFrame(Data)
#df = pd.DataFrame(Data,columns=['Country','GDP_STATE'])

# %%
df.head()
# Out:
#    Country    GDP
# 0      USA  45000
# 1   Canada  42000
# 2  Germany  52000
# 3       UK  49000
# 4   France  47000

# %%
df.plot(x ='Country',y='GDP', figsize=(10, 10),kind = 'scatter');
#plt.show()

# %%
df.plot(x ='Country',y='GDP', figsize=(10, 10),kind = 'line');
#plt.show()
# Out:
# c:\users\danie\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
df.plot(x ='Country',y='GDP', figsize=(10, 10),kind = 'box');#bar box kde pie density hexbin
#plt.show()

# %%
df.plot(x ='Country',y='GDP', figsize=(10, 10),kind = 'bar');
#plt.show()

# %% [markdown]
# ###Piechart from DATAFRAME

# %%
Data = {'Tasks': [300,500,700]}
df = pd.DataFrame(Data,columns=['Tasks'])

# %%
df.head()
# Out:
#    Tasks
# 0    300
# 1    500
# 2    700

# %%
df = pd.DataFrame(Data,columns=['Tasks'],
                  index = ['Tasks Pend','Tasks hold','Tasks Com'])
df.head()
# Out:
#             Tasks
# Tasks Pend    300
# Tasks hold    500
# Tasks Com     700

# %%
df.plot.pie(y='Tasks',figsize=(10, 10),autopct='%1.1f%%', startangle=90);
#plt.show()

# %%
#### Grouby Pandas

# %%
url_superficie = "https://it.wikipedia.org/wiki/Primi_100_comuni_italiani_per_superficie"

# %%
comuni_superficie = pd.read_html(url_superficie,
                                 attrs={"class":"wikitable"},
                                 header=0)
comuni_superficie = comuni_superficie[0]

#comuni_superficie.columns=[['Pos.','Comune','Regione','Provincia','Superficie']]

# %%
#comuni_superficie.head()
# Out:
#    Pos.     Comune         Regione Provincia Superficie (km²)
# 0     1       Roma           Lazio      Roma         1 287,36
# 1     2    Ravenna  Emilia-Romagna   Ravenna            65382
# 2     3  Cerignola          Puglia    Foggia            59393
# 3     4       Noto         Sicilia  Siracusa            55499
# 4     5    Sassari        Sardegna   Sassari            54704

# %%
comuni_superficie= comuni_superficie[1:]

# %%
comuni_superficie['Superficie (km²)']=comuni_superficie['Superficie (km²)'].astype('Int64')
# Out:
# C:\Users\libero.bo\AppData\Local\Temp\ipykernel_18600\4096769789.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comuni_superficie['Superficie (km²)']=comuni_superficie['Superficie (km²)'].astype('Int64')

# %%
comuni_superficie.groupby('Regione').mean() #aggregare i dati secondo un padre, in questo caso abbruzzo
# Out:
# C:\Users\libero.bo\AppData\Local\Temp\ipykernel_18600\2630618129.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   comuni_superficie.groupby('Regione').mean()
#                           Pos.  Superficie (km²)
# Regione
# Abruzzo               9.000000           47391.0
# Basilicata           54.666667           29641.0
# Calabria             52.333333      28937.666667
# Emilia-Romagna       56.200000           31154.1
# Lazio                38.666667      32106.333333
# Liguria              80.000000           24029.0
# Lombardia            94.500000           22701.5
# Marche               84.333333           24168.0
# Puglia               46.210526      33034.263158
# Sardegna             62.625000         29839.375
# Sicilia              46.300000          32300.15
# Toscana              52.142857      29941.357143
# Trentino-Alto Adige  56.000000           27485.0
# Umbria               32.142857      36175.285714
# Veneto               49.000000           30853.0

# %%
reg = comuni_superficie.groupby('Regione')
reg.aggregate([np.mean, np.std, pd.Series.count])
# Out:
# C:\Users\libero.bo\AppData\Local\Temp\ipykernel_18600\53420394.py:2: FutureWarning: ['Comune', 'Provincia'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   reg.aggregate([np.mean, np.std, pd.Series.count])
#                           Pos.                  Superficie (km²)  \
#                           mean        std count             mean
# Regione
# Abruzzo               9.000000        NaN     1          47391.0
# Basilicata           54.666667  33.321665     3          29641.0
# Calabria             52.333333  26.407070     3     28937.666667
# Emilia-Romagna       56.200000  30.828558    10          31154.1
# Lazio                38.666667  19.655364     3     32106.333333
# Liguria              80.000000        NaN     1          24029.0
# Lombardia            94.500000   2.121320     2          22701.5
# Marche               84.333333  24.542480     3          24168.0
# Puglia               46.210526  29.628400    19     33034.263158
# Sardegna             62.625000  32.762947     8        29839.375
# Sicilia              46.300000  27.380554    20         32300.15
# Toscana              52.142857  26.590505    14     29941.357143
# Trentino-Alto Adige  56.000000  24.041631     2          27485.0
# Umbria               32.142857  20.860078     7     36175.285714
# Veneto               49.000000  29.461840     3          30853.0
#
#
#                               std count
# Regione
# Abruzzo                       NaN     1
# Basilicata            8419.030110     3
# Calabria              5408.599850     3
# Emilia-Romagna       13146.217719    10
# Lazio                 7376.151051     3
# Liguria                       NaN     1
# Lombardia               40.305087     2
# Marche                2632.717987     3
# Puglia               10048.492396    19
# Sardegna             11275.484278     8
# Sicilia               9656.570331    20
# Toscana               7114.648125    14
# Trentino-Alto Adige   3877.773588     2
# Umbria                9897.267396     7
# Veneto                9300.741315     3

# %%
comuni_superficie.groupby('Regione')['Superficie (km²)'].count()
# Out:
# Regione
# Abruzzo                 1
# Basilicata              3
# Calabria                3
# Emilia-Romagna         10
# Lazio                   3
# Liguria                 1
# Lombardia               2
# Marche                  3
# Puglia                 19
# Sardegna                8
# Sicilia                20
# Toscana                14
# Trentino-Alto Adige     2
# Umbria                  7
# Veneto                  3
# Name: Superficie (km²), dtype: int64

# %%
comuni_superficie.groupby('Regione')['Superficie (km²)'].count().sort_values(ascending=False)
# Out:
# Regione
# Sicilia                20
# Puglia                 19
# Toscana                14
# Emilia-Romagna         10
# Sardegna                8
# Umbria                  7
# Basilicata              3
# Calabria                3
# Lazio                   3
# Marche                  3
# Veneto                  3
# Lombardia               2
# Trentino-Alto Adige     2
# Abruzzo                 1
# Liguria                 1
# Name: Superficie (km²), dtype: int64

# %%
### Esercizio PETS

# %%
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})

#df[['name','age','gender','state','num_children','num_pets']]
df
# Out:
#     name  age gender       state  num_children  num_pets
# 0   john   23      M  california             2         5
# 1   mary   78      F          dc             0         1
# 2  peter   22      M  california             0         0
# 3   jeff   19      M          dc             3         5
# 4   bill   45      M  california             2         2
# 5   lisa   33      F       texas             1         2
# 6   jose   20      M       texas             4         3

# %%
#df.to_csv('pets.csv',index=False)

# %%
df.plot(kind='scatter',x='num_children',y='num_pets',color='purple');

# %%
df.plot(kind='scatter',x='age',y='num_pets',color='green');

# %%
df.plot(kind='scatter',x='age',y='num_children',color='red');

# %%
df.plot(kind='bar',x='name',y='age');

# %%
df.plot(kind='line',x='name',y='num_children')
df.plot(kind='line',x='name',y='num_pets', color='red');

#plt.show()

# %%
# gca stands for 'get current axis'
ax = plt.gca()
df.plot(kind='line',x='name',y='num_children',ax=ax)
df.plot(kind='line',x='name',y='num_pets', color='red', ax=ax)

#plt.show()
# Out:
# <Axes: xlabel='name'>

# %%
df.groupby('num_children').size().plot(kind='bar');

# %%
df.groupby('num_pets').size().plot(kind='bar');

# %%
df.groupby('state').size().plot(kind='bar');

# %%
df.groupby(['state','gender']).size().plot(kind='bar');

# %%
df.groupby(['state','gender']).size().unstack().plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='state'>

# %%
df.groupby(['gender','state']).size().unstack().plot(kind='bar',stacked=True,figsize=(10, 10))
plt.legend(loc='upper left')

# %%
df[['age']].plot(kind='hist',bins=[0,20,40,60,80,100],
                 rwidth=0.9,figsize=(10, 10),color='green');
#plt.legend(loc='upper left');

# %%
df.groupby(['gender','state']).size().groupby(level=0).apply(lambda x: 100 * x / x.sum()  \
).unstack().plot(kind='bar',stacked=True,legend='reverse',figsize=(10, 10));
#).unstack().plot(kind='bar',stacked=True,figsize=(10, 10));  # legend not reversed


plt.title('Amount of records by Gender and State, normalized')

#import matplotlib.ticker as mtick
#plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter());  #aggiungere la % sugli ass
# Out:
# Text(0.5, 1.0, 'Amount of records by Gender and State, normalized')

# %% [markdown]
# ## DateHist

# %%
df = pd.DataFrame({
    'nome':['john','lisa','peter','carl','linda','betty'],
    'data_nascita':[
        '01/21/1988','03/10/1977','07/25/1999','01/22/1977','09/30/1968','09/15/1970'
    ]
})
df
# Out:
#     nome data_nascita
# 0   john   01/21/1988
# 1   lisa   03/10/1977
# 2  peter   07/25/1999
# 3   carl   01/22/1977
# 4  linda   09/30/1968
# 5  betty   09/15/1970

# %%
df.dtypes
# Out:
# nome            object
# data_nascita    object
# dtype: object

# %%
df['data_nascita'] = pd.to_datetime(df['data_nascita'],infer_datetime_format=True)

# %%
df.dtypes
# Out:
# nome                    object
# data_nascita    datetime64[ns]
# dtype: object

# %%
df['data_nascita'].map(lambda d: d.month).plot(kind='hist')
#df['data_nascita'].map(lambda d: d.month).plot(kind='hist',figsize=(10, 10))
plt.xlabel('Mesi in numero');
